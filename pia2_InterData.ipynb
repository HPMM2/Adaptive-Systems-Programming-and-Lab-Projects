# %% [markdown]
# # PIA Entrega 2

# %% [markdown]
# Equipo Interdata
#
# * Diego Huerta Serrano 1930907 ITS
# * Heidi Pamela Martinez Martinez 1952947 ITS
# * Melida Krystal Mendoza Ventura 2077884 ITS
# * José Francisco Jasso González 1724347 ITS
# * Yareth Yassari Toto Hernández 1992340 ITS

# %% [markdown]
# ## Motivacion y justificacion

# %% [markdown]
# La razón principal por la que este problema es relevante son las decisiones de inversión. Dado que los inversores y los distribuidores usan el pronóstico del precio de bitcoin para tomar decisiones otra razón podría ser la aceptación comercial, ya que el pronóstico del precio de bitcoins la expectativa de un aumento en el valor puede aumentar la aceptación.
#
# Los modelos de aprendizaje automático pueden adaptarse continuamente a medida que se generan nuevos datos, lo que permite la actualización en tiempo real de los pronósticos. Los datos financieros suelen ser altamente no lineales y multidimensionales, lo que hace que el aprendizaje automático sea ideal para identificar patrones y relaciones difíciles de captar manualmente.

# %%
#Importar la libreria pandas
import pandas as pd

# %%
#Leer el archivo CSV
pd.read_csv('bitcoin_diario.csv')
# Out:
#             unix                 date   symbol      open      high       low  \
# 0     1646092800  2022-03-01 00:00:00  BTC/USD  43221.71  43626.49  43185.48
# 1     1646006400  2022-02-28 00:00:00  BTC/USD  37717.10  44256.08  37468.99
# 2     1645920000  2022-02-27 00:00:00  BTC/USD  39146.66  39886.92  37015.74
# 3     1645833600  2022-02-26 00:00:00  BTC/USD  39242.64  40330.99  38600.00
# 4     1645747200  2022-02-25 00:00:00  BTC/USD  38360.93  39727.97  38027.61
# ...          ...                  ...      ...       ...       ...       ...
# 2646  1417478400  2014-12-02 00:00:00  BTC/USD    378.39    382.86    375.23
# 2647  1417392000  2014-12-01 00:00:00  BTC/USD    376.40    382.31    373.03
# 2648  1417305600  2014-11-30 00:00:00  BTC/USD    376.57    381.99    373.32
# 2649  1417219200  2014-11-29 00:00:00  BTC/USD    376.42    386.60    372.25
# 2650  1417132800  2014-11-28 00:00:00  BTC/USD    363.59    381.34    360.57
#
#          close    Volume BTC    Volume USD
# ...

# %%
#Desplegar las primeras n lineas
df=pd.read_csv('bitcoin_diario.csv')
print(df.head(10))
# Out:
#          unix                 date   symbol      open      high       low  \
# 0  1646092800  2022-03-01 00:00:00  BTC/USD  43221.71  43626.49  43185.48
# 1  1646006400  2022-02-28 00:00:00  BTC/USD  37717.10  44256.08  37468.99
# 2  1645920000  2022-02-27 00:00:00  BTC/USD  39146.66  39886.92  37015.74
# 3  1645833600  2022-02-26 00:00:00  BTC/USD  39242.64  40330.99  38600.00
# 4  1645747200  2022-02-25 00:00:00  BTC/USD  38360.93  39727.97  38027.61
# 5  1645660800  2022-02-24 00:00:00  BTC/USD  37253.26  39720.00  34324.05
# 6  1645574400  2022-02-23 00:00:00  BTC/USD  38269.94  39303.24  37060.16
# 7  1645488000  2022-02-22 00:00:00  BTC/USD  37036.98  38463.88  36368.99
# 8  1645401600  2022-02-21 00:00:00  BTC/USD  38384.09  39494.11  36810.72
# 9  1645315200  2022-02-20 00:00:00  BTC/USD  40108.62  40151.62  37974.18
#
#       close   Volume BTC    Volume USD
# 0  43185.48    49.006289  2.116360e+06
# 1  43178.98  3160.618070  1.364723e+08
# ...

# %% [markdown]
# (1) Información del dataframe. Obtén los siguientes datos con Pandas:
#
#     a. Cantidad de renglones del dataframe
#     b. Cantidad de columnas del dataframe

# %%
len(df.index)
# Out:
# 2651

# %%
len(df.columns)
# Out:
# 9

# %% [markdown]
# (2) Descripción del dataframe. Realiza lo siguiente:
#
#     a. Despliega un resumen estadístico de las columnas del dataframe (tip: método .describe())
#     b. Interpreta esta descripción: ¿Qué les llamó la atención de esta información?
#     c. ¿Cuáles son los datos más relevantes de la columna close?

# %%
df.describe()
# Out:
#                unix          open          high           low         close  \
# count  2.651000e+03   2651.000000   2651.000000   2651.000000   2651.000000
# mean   1.531613e+09  11693.189332  12038.562912  11296.539461  11709.326213
# std    6.613247e+07  16272.554746  16739.237000  15718.297511  16282.908704
# min    1.417133e+09    162.000000    212.840000    152.400000    162.000000
# 25%    1.474373e+09    654.680000    664.460000    640.050000    654.370000
# 50%    1.531613e+09   6408.950000   6540.000000   6312.000000   6407.770000
# 75%    1.588853e+09  10708.620000  10956.240000  10303.755000  10726.425000
# max    1.646093e+09  67547.490000  69000.000000  66250.000000  67559.000000
#
#          Volume BTC    Volume USD
# count  2.651000e+03  2.651000e+03
# mean   1.330041e+07  6.099369e+07
# std    4.715366e+07  1.072838e+08
# min    0.000000e+00  0.000000e+00
# 25%    5.357883e+03  9.516170e+03
# 50%    1.503310e+04  2.288982e+07
# 75%    3.435336e+06  8.018383e+07
# ...

# %% [markdown]
# Nos llamo la atencion de esta informacion que en promedio el bitcoin cierra con un valor mas alto del que comenzo el dia. Tambien la alta desviacion que puede presentar.

# %% [markdown]
# Los datos mas importantes de la columna close son la media y el low.

# %% [markdown]
# (3) Tipos de datos. Realiza lo siguiente:
#
#     a. Utilizando Pandas, obtén a qué tipo de dato (variable) corresponde cada columna del dataframe (tip: método .info()).
#     b. ¿De qué tipo es la columna date? Incluye tu respuesta en una celda de texto.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2651 entries, 0 to 2650
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   unix        2651 non-null   int64
#  1   date        2651 non-null   object
#  2   symbol      2651 non-null   object
#  3   open        2651 non-null   float64
#  4   high        2651 non-null   float64
#  5   low         2651 non-null   float64
#  6   close       2651 non-null   float64
#  7   Volume BTC  2651 non-null   float64
#  8   Volume USD  2651 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 186.5+ KB

# %% [markdown]
# El tipo de dato de date es objeto.

# %% [markdown]
# (4) Gráfica. Utiliza matplotlib y seaborn para graficar la columna close con respecto al tiempo.

# %%
import matplotlib.pyplot as plt

# %%
df.plot(x="date", y="close");
